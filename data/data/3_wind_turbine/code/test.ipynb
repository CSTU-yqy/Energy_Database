# %%
# !! curl -X GET "https://curl -X GET "https://eersc.usgs.gov/api/uswtdb/v1/turbines" -H "Accept: application/json" > windturbine.json

# %%
import pandas as pd

# Read the JSON file into a DataFrame
df = pd.read_json('/data/data/energy_data/3_wind_turbine/data/windturbine.json')

df
# Out:
#        case_id    faa_ors           faa_asn  usgs_pr_id t_state  \
# 0      3123233  40-097764  2021-WTW-7887-OE         NaN      OK
# 1      3123609  40-097526  2021-WTW-7898-OE         NaN      OK
# 2      3119868  40-097497  2021-WTW-7912-OE         NaN      OK
# 3      3123202  40-097556  2021-WTW-7875-OE         NaN      OK
# 4      3124077  40-097543  2021-WTW-7885-OE         NaN      OK
# ...        ...        ...               ...         ...     ...
# 72726  3053232  36-120351  2015-WTE-5788-OE         NaN      NY
# 72727  3101958  48-171972  2020-WTW-2021-OE         NaN      TX
# 72728  3040944  48-024978   2011-WTW-352-OE     41364.0      TX
# 72729  3055917  08-072245  2015-WTW-9994-OE         NaN      CO
# 72730  3055918  08-072237  2015-WTW-9995-OE         NaN      CO
#
#              t_county  t_fips                  p_name  p_year  p_tnum  ...  \
# 0        Ellis County   40045           25 Mile Creek  2022.0      60  ...
# ...

# %%
df.to_csv('../data/windturbine.csv',index = False)
